# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQcbC9JNrtvj6sdkH2pDn8Xg2u5uy_TTZ8Mzg&s)

# %% [markdown]
# -------
# <h2> Table of Contents </h2>
#
# <ol style= "color:brown;
#             font-size:20px;">
#     <li> Import Libraries</li>
#     <li> Read Data</li>
#     <li> Get some information about the data</li>
#     <li> Data Cleaning</li>
#     <li> Data Visualization & Getting Analysis </li>
#     <li> Insights </li>
#
# </ol>

# %% [markdown]
# ----
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ---
# ## Read Data

# %%
df=pd.read_csv('/kaggle/input/udemy-courses/udemy_courses.csv')

# %% [markdown]
# ----
# ## Get some information about the data

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration   published_timestamp           subject
# 0               1.5  2017-01-18T20:58:58Z  Business Finance
# 1              39.0  2017-03-09T16:34:20Z  Business Finance
# 2               2.5  2016-12-19T19:26:30Z  Business Finance
# 3               3.0  2017-05-30T20:07:24Z  Business Finance
# 4               2.0  2016-12-13T14:57:18Z  Business Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
df.sample(10)
# Out:
#       course_id                                       course_title  \
# 2473     513528              Curso de guitarra para principiantes.
# 2219     744034         Piano With Willie: Jazz & Gospel Exercises
# 3640     939536                 Learn basics of HTML in 30 Minutes
# 3498      41356  Create a Responsive Business Website with Word...
# 668     1036456                           Basics of Private Equity
# 868      466774             Learn About Bitcoin and Bitcoin Mining
# 2734     876544                         ASP.NET Web API 2 Hands-On
# 2074     650836                          Introduction to Ukulele 1
# 3504    1007766  How to create Paypal and Credit card Payment B...
# 223      738900  Trading Seasonal Price Patterns in Stocks, Fut...
#
#                                                     url  is_paid  price  \
# 2473  https://www.udemy.com/curso-de-guitarra-para-p...     True     20
# 2219  https://www.udemy.com/piano-with-willie-jazz-g...     True     40
# 3640        https://www.udemy.com/learn-basics-of-html/     True     20
# 3498  https://www.udemy.com/creating-a-business-webs...     True     95
# 668     https://www.udemy.com/basics-of-private-equity/     True     60
# 868   https://www.udemy.com/learn-about-bitcoin-and-...     True     20
# 2734   https://www.udemy.com/aspnet-web-api-2-hands-on/     True     20
# 2074     https://www.udemy.com/introduction-to-ukulele/     True     20
# 3504  https://www.udemy.com/how-to-create-paypal-and...     True     65
# 223   https://www.udemy.com/trading-seasonal-price-p...     True    200
#
#       num_subscribers  num_reviews  num_lectures               level  \
# 2473                4            0             7      Beginner Level
# 2219               56            3            28  Intermediate Level
# 3640              945           17            11      Beginner Level
# 3498             1659           73            38          All Levels
# 668                 9            2             6  Intermediate Level
# 868               520           10             9      Beginner Level
# 2734             2660          276            16          All Levels
# 2074              630           25            27      Beginner Level
# 3504              578            6             8      Beginner Level
# 223              1094            8            13      Beginner Level
#
#       content_duration   published_timestamp              subject
# 2473          1.000000  2015-06-11T15:55:19Z  Musical Instruments
# 2219          2.000000  2016-04-13T06:57:11Z  Musical Instruments
# 3640          0.550000  2016-09-02T16:37:09Z      Web Development
# 3498          5.500000  2013-03-25T01:44:54Z      Web Development
# 668           0.666667  2017-05-09T22:19:30Z     Business Finance
# 868           0.533333  2015-05-01T23:05:13Z     Business Finance
# 2734          1.500000  2016-06-19T20:10:58Z      Web Development
# 2074          1.000000  2015-12-01T19:23:03Z  Musical Instruments
# 3504          1.000000  2016-11-17T20:57:25Z      Web Development
# 223           2.000000  2016-03-30T04:56:57Z     Business Finance

# %%
df.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.678000e+03  3678.000000      3678.000000   3678.000000   3678.000000
# mean   6.759720e+05    66.049483      3197.150625    156.259108     40.108755
# std    3.432732e+05    61.005755      9504.117010    935.452044     50.383346
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.076925e+05    20.000000       111.000000      4.000000     15.000000
# 50%    6.879170e+05    45.000000       911.500000     18.000000     25.000000
# 75%    9.613555e+05    95.000000      2546.000000     67.000000     45.750000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %% [markdown]
# ---
# ## Data Cleaning

# %%
df.isna().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
# remove unnecassary columns

df.drop(['url','course_id'],axis=1,inplace=True)

# %%
# convert the is_paid column from boolean to string
# convert the published_timestamp column from object to datetime

df['is_paid']=df['is_paid'].astype(str)
df['published_timestamp']=pd.to_datetime(df['published_timestamp'])

# %%
df.is_paid.replace(['True', 'False'], ['paid', 'unpaid'], inplace=True)

# %%
# display the duplicated rows

df[df.duplicated()]
# Out:
#                                            course_title is_paid  price  \
# 787   Essentials of money value: Get a financial Life !    paid     20
# 788   Introduction to Forex Trading Business For Beg...    paid     20
# 894                  Understanding Financial Statements    paid     25
# 1100                  CFA Level 2- Quantitative Methods    paid     40
# 1473                             MicroStation - Células    paid     20
# 2561  Learn Web Designing & HTML5/CSS3 Essentials in...    paid     75
#
#       num_subscribers  num_reviews  num_lectures           level  \
# 787                 0            0            20      All Levels
# 788                 0            0            27  Beginner Level
# 894                 0            0            10      All Levels
# 1100                0            0            35      All Levels
# 1473                0            0             9  Beginner Level
# 2561            43285          525            24      All Levels
#
#       content_duration       published_timestamp           subject
# 787           0.616667 2016-05-16 18:28:30+00:00  Business Finance
# 788           1.500000 2017-04-23 16:19:01+00:00  Business Finance
# 894           1.000000 2016-12-15 14:56:17+00:00  Business Finance
# 1100          5.500000 2017-07-02 14:29:35+00:00  Business Finance
# 1473          0.616667 2014-04-15 21:48:55+00:00    Graphic Design
# 2561          4.000000 2013-01-03 00:55:31+00:00   Web Development

# %%
# remove duplicated rows

df.drop_duplicates(inplace=True)

# %%
# function that remove outliers 

def detect_outliers(column):
    q3=np.quantile(df[column],0.75)
    q1=np.quantile(df[column],0.25)
    
    iqr=q3-q1
    
    lower_limit = q1-(1.5*iqr)
    higher_limit = q3 +(1.5*iqr)
    
    cleaned_data = df[(df[column] > lower_limit) & (df[column] < higher_limit)]
    return cleaned_data

# %%
# remove outliers from columns

columns=['price','num_subscribers','num_reviews','num_lectures','content_duration']
for column in columns:
    df=detect_outliers(column)

# %%
# display the data after edits

df.head()
# Out:
#                                         course_title is_paid  price  \
# 0                 Ultimate Investment Banking Course    paid    200
# 2  Financial Modeling for Business Analysts and C...    paid     45
# 3  Beginner to Pro - Financial Analysis in Excel ...    paid     95
# 4       How To Maximize Your Profits Trading Options    paid    200
# 8  Options Trading 3 : Advanced Stock Profit and ...    paid    195
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
# 8             5172           34            38        Expert Level
#
#    content_duration       published_timestamp           subject
# 0               1.5 2017-01-18 20:58:58+00:00  Business Finance
# 2               2.5 2016-12-19 19:26:30+00:00  Business Finance
# 3               3.0 2017-05-30 20:07:24+00:00  Business Finance
# 4               2.0 2016-12-13 14:57:18+00:00  Business Finance
# 8               2.5 2015-05-28 00:14:03+00:00  Business Finance

# %%
df.shape
# Out:
# (2415, 10)

# %%
df.describe()
# Out:
#              price  num_subscribers  num_reviews  num_lectures  \
# count  2415.000000      2415.000000  2415.000000   2415.000000
# mean     57.648033       940.799586    17.716770     23.267081
# std      54.588127      1227.219640    21.440021     14.303416
# min       0.000000         0.000000     0.000000      0.000000
# 25%      20.000000        50.000000     3.000000     12.000000
# 50%      40.000000       420.000000     9.000000     20.000000
# 75%      70.000000      1357.500000    25.000000     30.000000
# max     200.000000      6134.000000   101.000000     76.000000
#
#        content_duration
# count       2415.000000
# mean           2.060697
# std            1.254376
# min            0.000000
# 25%            1.000000
# 50%            1.500000
# 75%            3.000000
# max            5.500000

# %% [markdown]
# ____
# ## Data Visualization & Getting Analysis

# %%
# Paid vs Free Courses

plt.figure(figsize=(10,7))
sns.countplot(x='is_paid',data=df)
plt.xlabel('Is_Paid',fontsize=12)
plt.ylabel('Courses Count',fontsize=12)
plt.title('Paid Vs Free Courses',fontsize=15)
plt.show()

# %%
df['is_paid'].value_counts()
# Out:
# is_paid
# paid      2288
# unpaid     127
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,7))
df['is_paid'].value_counts().plot(kind='bar')
plt.xlabel('Is_Paid',fontsize=12)
plt.ylabel('Courses Count',fontsize=12)
plt.title('Paid vs Free Courses',fontsize=15)
plt.show()

# %% [markdown]
# ### <font color = red> Result </font>: Most of the courses are paid

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='level',data=df)
plt.xlabel('Levels',fontsize=12)
plt.ylabel('Courses Count',fontsize=12)
plt.title('Levels vs Courses Count',fontsize=15)
plt.show()

# %% [markdown]
# ### <font color = red> Result </font>: Most of the courses are All Levels and Beginner Level

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='subject',data=df)
plt.xlabel('Subjects',fontsize=12)
plt.ylabel('Courses Count',fontsize=12)
plt.title('Subjects vs Courses Count',fontsize=15)
plt.show()

# %%
df['subject'].value_counts()
# Out:
# subject
# Business Finance       906
# Musical Instruments    546
# Web Development        513
# Graphic Design         450
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))

plt.pie(x=df['subject'].value_counts().values,
        labels=df['subject'].value_counts().index,
        autopct="%.1f%%",
        explode=[.2,.1,0,0],
        shadow=True
       )
plt.show()

# %% [markdown]
# ### <font color = red> Result </font>: Most required field is Business Finance

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='is_paid',hue='subject',data=df)
plt.xlabel('Is_Paid',fontsize=12)
plt.ylabel('Courses Count',fontsize=12)
plt.show()

# %% [markdown]
# ### <font color = red> Result </font>: Most Paid and Free Courses are Business Finance

# %%
df.corr(numeric_only=True)
# Out:
#                      price  num_subscribers  num_reviews  num_lectures  \
# price             1.000000         0.071248     0.118132      0.204151
# num_subscribers   0.071248         1.000000     0.511564      0.036341
# num_reviews       0.118132         0.511564     1.000000      0.167380
# num_lectures      0.204151         0.036341     0.167380      1.000000
# content_duration  0.176006         0.016823     0.169466      0.621993
#
#                   content_duration
# price                     0.176006
# num_subscribers           0.016823
# num_reviews               0.169466
# num_lectures              0.621993
# content_duration          1.000000

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.show()

# %%
# Price vs Num of Subscribers

plt.figure(figsize=(10,6))
sns.regplot(x='price',y='num_subscribers',data=df)
plt.xlabel('Price',fontsize=12)
plt.ylabel('Number of Subscribers',fontsize=12)
plt.title('Price vs Num of Subscribers',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='price',y='num_subscribers',data=df)
plt.xlabel('Price',fontsize=12)
plt.ylabel('Number of Subscribers',fontsize=12)
plt.title('Price vs Num of Subscribers',fontsize=15)
plt.show()

# %% [markdown]
# ### <font color = red> Result </font>: Course Price Doesn't Affect The Number Of Subscribers

# %%
# Price vs Num of Reviews

plt.figure(figsize=(10,6))
sns.regplot(x='price',y='num_reviews',data=df)
plt.xlabel('Price',fontsize=12)
plt.ylabel('Number of Reviews',fontsize=12)
plt.title('Price vs Num of Reviews',fontsize=15)
plt.show()

# %% [markdown]
# ### <font color = red> Result </font>: Course Price Doesn't Affect The Number Of Reviews

# %%
# Price vs Content Duration

plt.figure(figsize=(10,6))
sns.regplot(x='price',y='content_duration',data=df)
plt.xlabel('Price',fontsize=12)
plt.ylabel('Content Duration',fontsize=12)
plt.title('Price vs Content Duration',fontsize=15)
plt.show()

# %% [markdown]
# ### <font color = red> Result </font>: Content Duration Doesn't Affect The Course Price

# %%
# Content Duration vs Number of Subscribers

plt.figure(figsize=(10,6))
sns.regplot(x='num_subscribers',y='content_duration',data=df)
plt.xlabel('Num of Subscribers',fontsize=12)
plt.ylabel('Content Duration',fontsize=12)
plt.title('Content Duration vs Number of Subscribers',fontsize=13)
plt.show()

# %% [markdown]
# ### <font color = red> Result </font>: Content Duration Doesn't Affect The Number of Subscribers

# %%
# Num of Subscribers vs Num of Reviews

plt.figure(figsize=(10,6))
sns.regplot(x='num_subscribers',y='num_reviews',data=df)
plt.xlabel('Num of Subscribers',fontsize=12)
plt.ylabel('Num of Reviews',fontsize=12)
plt.title('Num of Subscribers vs Num of Reviews',fontsize=13)
plt.show()

# %% [markdown]
# ### <font color = red> Result </font>: Number of Subscribers Affect The Number of Reviews

# %%
plt.figure(figsize=(10,6))
sns.stripplot(x='subject',y='price',hue='level',data=df,dodge=True)
plt.show()

# %% [markdown]
# -----
# ## <font color=red> Insights </font>
# <ul style= "color:black;
#             font-size:18px;">
#     <li> Most of the courses are paid</li>
#     <li> Most of the courses are All Levels and Beginner Level</li>
#     <li> Most Paid and Free Courses are Business Finance</li>
#     <li> Course Price Doesn't Affect The Number Of Subscribers</li>
#     <li> Course Price Doesn't Affect The Number Of Reviews</li>
#     <li> Content Duration Doesn't Affect The Course Price</li>
#     <li> Content Duration Doesn't Affect The Number of Subscribers </li>
#     <li> Number of Subscribers Affect The Number of Reviews
#  </li>
# </ul>
